# %%
# %pylab nbagg
import local_utils as lut
import nugridse as nuse

# change data_dir to a name where your output data from the ppn_nova example are:
data_dir='/home/dpa/my_nugrid/ppn_nova'

# begin counting figures
ifig=0
for i in range(0,10000):
    close(i)

####section to include at the beginnning of your notebook that will suppress output of unnecessary information
import os
from contextlib import contextmanager
@contextmanager
def redirect_stdout(new_target):
    old_target, sys.stdout = sys.stdout, new_target
    try:
        yield new_target
    finally:
        sys.stdout = old_target
def get_devnull():
    #return open(os.devnull, "w")
    return open('log_stuff.txt', "w") #where all the stuff goes you don't want to see
####
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# specify a path to a file with element abundances that will be used for scaling in the plots
# these can be either the solar abundances if you want to plot abundances relative to the solar ones (ref=-1) or
# the initial abundances if you want to plot abundances relative to the initial ones (ref=-2)
#
# these are the Grevesse & Noels (1993) solar abundances
sol_ab="iniab1.9E-02GN93.ppn"
# these are the Asplund (2005) solar abundances with the Lodders et al. (2003) isotopic ratios
#sol_ab="iniab1.2E-02As05.ppn"
# if it is necessary, the file "iniab1.2E-02As05.ppn" can be prepared with the initial_abundance_tool.tgz
# in nugrid/frames/mppnp/USEEPP without the Cunha corrected NE20 abundance

# %%
# comparison of the initial abundances for the ppn and mppnp_hif simulations of the i process in Sakurai's object
ifig=ifig+1
close(ifig),lut.select_fig(ifig)
with get_devnull() as devnull, redirect_stdout(devnull):
    lut.plot_ppn_abund(sol_ab,data_dir,1,zrange=[0,22],yrange=[-3,5],shape='mo',msize=6,labels=True,ref=-1,title="solar-scaled ppn_nova abundances")
    lut.plot_ppn_abund(sol_ab,data_dir,380,zrange=[0,22],yrange=[-3,5],shape='cd',msize=6,labels=True,ref=-1,title="solar-scaled ppn_nova abundances")
# Out:
# <img src="data:image/png;base64,...">
